# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('userSimilarity.csv')

# %%
df.head()
# Out:
#    user       769      1333      1442      1527      2000      2213      2455
# 0   769  1.000000  0.335204  0.037336 -0.494102  0.162405  0.022145 -0.019031  \
# 1  1333  0.335204  1.000000 -0.237730 -0.324644  0.432416 -0.129755  0.021222
# 2  1442  0.037336 -0.237730  1.000000  0.437741  0.080413  0.099581  0.290808
# 3  1527 -0.494102 -0.324644  0.437741  1.000000  0.049397  0.169711 -0.025649
# 4  2000  0.162405  0.432416  0.080413  0.049397  1.000000 -0.329344  0.382305
#
#        2469      2787  ...   2648287   2648351   2648465   2648502   2648589
# 0 -0.311071  0.331131  ...  0.288319 -0.528059  0.194701  0.335825  0.208031  \
# 1 -0.042043  0.150671  ...  0.197185 -0.130631  0.334084  0.381261  0.170863
# 2 -0.289068  0.241479  ...  0.288714  0.423560 -0.073502 -0.340926 -0.273551
# 3 -0.050443  0.172506  ...  0.388375  0.051503  0.116501 -0.405684 -0.167426
# 4 -0.217882  0.332038  ...  0.440580  0.093678  0.066710  0.097569  0.297330
#
# ...

# %%
df = df.fillna(0)

# %%
pcaDataset = []

# %%
#pca = PCA(n_components=5)
#model = pca.fit(df).transform(df)

for i in range(2,8):
    pca = PCA(n_components=i)
    model = pca.fit(df).transform(df)
    pcaDataset.append(model)

# %%
print(len(pcaDataset))
# Out:
# 6

# %%
# Plot scatter plots in each subplot
fig, axs = plt.subplots(3, 2, figsize=(10, 12))

# Flatten the axs array for easier indexing
axs = axs.flatten()

# Iterate over each subplot and plot the scatter plot
for i, ax in enumerate(axs):
    x = pcaDataset[i]
    ax.scatter(x[:,0], x[:,1], s=0.3, c='blue', alpha=0.5)
    ax.set_title(f'n_components = {i+2}')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()
print(sum(pcaDataset[1][:,0]-pcaDataset[0][:,0]))
# Out:
# 0.0

# %%
plt.scatter(model[:,0],model[:,1],s=0.5)

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

df = pd.read_csv('masterDf.csv')
df = df.fillna(0)

# Assuming you have your dataset stored in a NumPy array
dataset = df

# Create a KMeans object with the desired number of clusters (k)
kmeans = KMeans(n_clusters=2)

# Fit the model to your dataset
kmeans.fit(dataset)

# Retrieve the cluster labels assigned to each data point
labels = kmeans.labels_

# Retrieve the cluster centers
centroids = kmeans.cluster_centers_

# %%
## Plot the dataset and cluster assignments
plt.figure()
plt.scatter(dataset, dataset, c=labels)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='red', s=100)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('K-means Clustering')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## Plot the dataset and cluster assignments
# ----> 2 plt.figure()
#       3 plt.scatter(dataset, dataset, c=labels)
#       4 plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='red', s=100)
#
# NameError: name 'plt' is not defined
